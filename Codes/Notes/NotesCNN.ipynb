# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import csv
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D
# Out:
# Using TensorFlow backend.

# %%
vocab_size = 3000
embedding_dim = 128
max_length = 150
trunc_type = 'post'
padding_type = 'post'
oov_tok = '<OOV>'
training_portion = .8

# %%
df = pd.read_csv('cleaned.csv')

# %%
df = df.sample(frac=1)
X = df.keywords.values
y = df.label.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 50)

# %%
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
encoder = LabelEncoder()
encoder.fit(y)
y_train = encoder.transform(y_train)
y_test = encoder.transform(y_test)

# %%
encoder.inverse_transform([0,1,2,3,4])
# Out:
# array(['gastroenterology', 'neurology', 'orthopedic', 'radiology',
#        'urology'], dtype=object)

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(X_train) #only train
word_index = tokenizer.word_index
dict(list(word_index.items()))
# Out:
# {'<OOV>': 1,
#  'of': 2,
#  'and': 3,
#  'or': 4,
#  'ct': 5,
#  'to': 6,
#  'sample': 7,
#  'cervical': 8,
#  'mri': 9,
#  'ne': 10,
#  'the': 11,
#  'nerve': 12,
#  'brain': 13,
#  'spine': 14,
#  'medical': 15,
#  'transcription': 16,
#  'reports': 17,
#  'any': 18,
#  'hernia': 19,
#  'carpal': 20,
#  'disc': 21,
#  'lumbar': 22,
#  'artery': 23,
#  'anterior': 24,
#  'fracture': 25,
#  'disease': 26,
#  'tunnel': 27,
#  'carotid': 28,
#  'bladder': 29,
#  'ligament': 30,
#  'joint': 31,
#  'laparoscopic': 32,
#  'abdomen': 33,
#  'ultrasound': 34,
#  'inguinal': 35,
#  'colon': 36,
#  'scan': 37,
#  'pain': 38,
#  'bilateral': 39,
#  'knee': 40,
#  'tendon': 41,
#  'discectomy': 42,
#  'for': 43,
#  'type': 44,
#  'is': 45,
#  'syndrome': 46,
#  'stenosis': 47,
#  'removed': 48,
#  'date': 49,
#  'thesetranscribed': 50,
#  'examples': 51,
#  'are': 52,
#  'provided': 53,
#  'by': 54,
#  'various': 55,
#  'users': 56,
#  'andare': 57,
#  'reference': 58,
#  'purpose': 59,
#  'only': 60,
#  'mthelpline': 61,
#  'does': 62,
#  'not': 63,
#  'certify': 64,
#  'accuracy': 65,
#  'quality': 66,
#  'reportsthese': 67,
#  'transcribed': 68,
#  'may': 69,
#  'include': 70,
#  'some': 71,
#  'uncommon': 72,
#  'unusual': 73,
#  'formats': 74,
#  'this': 75,
#  'would': 76,
#  'be': 77,
#  'due': 78,
#  'preference': 79,
#  'dictating': 80,
#  'physician': 81,
#  'all': 82,
#  'names': 83,
#  'dates': 84,
#  'have': 85,
#  'beenchanged': 86,
#  'keep': 87,
#  'confidentiality': 88,
#  'resemblance': 89,
#  'name': 90,
#  'orplace': 91,
#  'anything': 92,
#  'else': 93,
#  'real': 94,
#  'world': 95,
#  'purely': 96,
#  'incidental': 97,
#  'spinal': 98,
#  'contrast': 99,
#  'internal': 100,
#  'repair': 101,
#  'prostate': 102,
#  'femoral': 103,
#  'stress': 104,
#  'mass': 105,
#  'cerebral': 106,
#  'transverse': 107,
#  'emg': 108,
#  'head': 109,
#  'cord': 110,
#  'colonoscopy': 111,
#  'distal': 112,
#  'needle': 113,
#  'lateral': 114,
#  'tourniquet': 115,
#  'renal': 116,
#  'fixation': 117,
#  'study': 118,
#  'lesion': 119,
#  'cuff': 120,
#  'release': 121,
#  'rotator': 122,
#  'lower': 123,
#  'cholecystectomy': 124,
#  'conduction': 125,
#  'biopsy': 126,
#  'degenerative': 127,
#  'images': 128,
#  'central': 129,
#  'pelvis': 130,
#  'fascia': 131,
#  'abdominal': 132,
#  'space': 133,
#  'loss': 134,
#  'extremity': 135,
#  'shoulder': 136,
#  'axial': 137,
#  'perfusion': 138,
#  'weakness': 139,
#  'vertebral': 140,
#  'incision': 141,
#  'bowel': 142,
#  'body': 143,
#  'tear': 144,
#  'proximal': 145,
#  'medial': 146,
#  'oblique': 147,
#  'tumor': 148,
#  'canal': 149,
#  'fusion': 150,
#  'fluid': 151,
#  'valve': 152,
#  'ulnar': 153,
#  'esophagus': 154,
#  'arthroplasty': 155,
#  'posterior': 156,
#  'decompression': 157,
#  'wall': 158,
#  'endoscopy': 159,
#  'gallbladder': 160,
#  'urinary': 161,
#  'radiculopathy': 162,
#  'bone': 163,
#  'muscle': 164,
#  'cancer': 165,
#  'visual': 166,
#  'with': 167,
#  'tissue': 168,
#  'hip': 169,
#  'tibial': 170,
#  'aortic': 171,
#  'catheter': 172,
#  'polyps': 173,
#  'numbness': 174,
#  'motor': 175,
#  'noncontrast': 176,
#  'muscles': 177,
#  'subdural': 178,
#  'myocardial': 179,
#  'hematoma': 180,
#  'myoview': 181,
#  'foraminal': 182,
#  'esophageal': 183,
#  'cystic': 184,
#  'temporal': 185,
#  'annular': 186,
#  'bulging': 187,
#  'angiogram': 188,
#  'screw': 189,
#  'external': 190,
#  'test': 191,
#  'echocardiogram': 192,
#  'ventricular': 193,
#  'herniation': 194,
#  'back': 195,
#  'block': 196,
#  'metatarsal': 197,
#  'paraspinal': 198,
#  'spondylosis': 199,
#  'injection': 200,
#  'dorsal': 201,
#  'reduction': 202,
#  'resection': 203,
#  'duct': 204,
#  'neural': 205,
#  'umbilical': 206,
#  'adenocarcinoma': 207,
#  'ankle': 208,
#  'esophagogastroduodenoscopy': 209,
#  'hemorrhage': 210,
#  'cholecystitis': 211,
#  'sac': 212,
#  'coronary': 213,
#  'cruciate': 214,
#  'neck': 215,
#  'duodenum': 216,
#  'therapy': 217,
#  'rectal': 218,
#  'lumbosacral': 219,
#  'disk': 220,
#  'nuclear': 221,
#  'cystoscopy': 222,
#  'ejection': 223,
#  'bleeding': 224,
#  'inflammatory': 225,
#  'aneurysm': 226,
#  'scrotal': 227,
#  'spect': 228,
#  'total': 229,
#  'arthroscopy': 230,
#  'collateral': 231,
#  'reflux': 232,
#  'tube': 233,
#  'appendectomy': 234,
#  'foot': 235,
#  'fraction': 236,
#  'coronal': 237,
#  'herniated': 238,
#  'gastric': 239,
#  'cecum': 240,
#  'stone': 241,
#  'upper': 242,
#  'chest': 243,
#  'complex': 244,
#  'root': 245,
#  'plate': 246,
#  'craniotomy': 247,
#  'node': 248,
#  'heart': 249,
#  'sinuses': 250,
#  'normal': 251,
#  'eeg': 252,
#  'systolic': 253,
#  'arthroscopic': 254,
#  'debridement': 255,
#  'liver': 256,
#  'memory': 257,
#  'endotracheal': 258,
#  'stomach': 259,
#  'appendicitis': 260,
#  'frontal': 261,
#  'sutures': 262,
#  'lymph': 263,
#  'osteotomy': 264,
#  'junction': 265,
#  'doppler': 266,
#  'ureteral': 267,
#  'difficulty': 268,
#  'mucosa': 269,
#  'thoracic': 270,
#  'subcutaneous': 271,
#  'function': 272,
#  'medialis': 273,
#  'cardiac': 274,
#  'views': 275,
#  'deep': 276,
#  'lobe': 277,
#  'sagittal': 278,
#  'acute': 279,
#  'venous': 280,
#  'compression': 281,
#  'deformity': 282,
#  'leg': 283,
#  'olympus': 284,
#  'flexor': 285,
#  'sinus': 286,
#  'imaging': 287,
#  'csf': 288,
#  'hct': 289,
#  'hardware': 290,
#  'penile': 291,
#  'ischemic': 292,
#  'hiatal': 293,
#  'trigger': 294,
#  'nucleus': 295,
#  'excision': 296,
#  'polyp': 297,
#  'epidural': 298,
#  'diagnostic': 299,
#  'examination': 300,
#  'video': 301,
#  'circumcision': 302,
#  'common': 303,
#  'pulmonary': 304,
#  'colonoscope': 305,
#  'polypectomy': 306,
#  'matter': 307,
#  'gastroesophageal': 308,
#  'cyst': 309,
#  'arthrosis': 310,
#  'achilles': 311,
#  'electrocautery': 312,
#  'adhesions': 313,
#  'angiography': 314,
#  'parietal': 315,
#  'exam': 316,
#  'response': 317,
#  'neuropathy': 318,
#  'hemorrhoids': 319,
#  'anesthesia': 320,
#  'biopsies': 321,
#  'sigmoid': 322,
#  'impingement': 323,
#  'pelvic': 324,
#  'ventral': 325,
#  'rate': 326,
#  'headaches': 327,
#  'rectum': 328,
#  'allograft': 329,
#  'foreign': 330,
#  'bovie': 331,
#  'wound': 332,
#  'hypertrophy': 333,
#  'prostatectomy': 334,
#  'region': 335,
#  'mitral': 336,
#  'atrial': 337,
#  'chronic': 338,
#  'patella': 339,
#  'toxin': 340,
#  'phalanx': 341,
#  'latency': 342,
#  'adenosine': 343,
#  'endoscopic': 344,
#  'pulposus': 345,
#  'instrumentation': 346,
#  'benign': 347,
#  'drainage': 348,
#  'penis': 349,
#  'infection': 350,
#  'partial': 351,
#  'sensory': 352,
#  'intracranial': 353,
#  'nausea': 354,
#  'hydrocele': 355,
#  'foley': 356,
#  'transurethral': 357,
#  'flexure': 358,
#  'white': 359,
#  'aphasia': 360,
#  'removal': 361,
#  'metzenbaum': 362,
#  'cspine': 363,
#  'gastrocnemius': 364,
#  'digital': 365,
#  'fetal': 366,
#  'right': 367,
#  'finger': 368,
#  'facet': 369,
#  'evoked': 370,
#  'ganglia': 371,
#  'subacromial': 372,
#  'testis': 373,
#  'plantar': 374,
#  'meniscus': 375,
#  'change': 376,
#  'pedicle': 377,
#  'intervertebral': 378,
#  'egd': 379,
#  'appendix': 380,
#  'carcinoma': 381,
#  'prostatic': 382,
#  'vicryl': 383,
#  'dysphagia': 384,
#  'scissors': 385,
#  'c': 386,
#  'stroke': 387,
#  'barium': 388,
#  'dysfunction': 389,
#  'bunionectomy': 390,
#  'sacroiliac': 391,
#  'vein': 392,
#  'tenosynovitis': 393,
#  'motion': 394,
#  'seizure': 395,
#  'gastrostomy': 396,
#  'mammogram': 397,
#  'urethral': 398,
#  'breast': 399,
#  'obstruction': 400,
#  'replacement': 401,
#  'left': 402,
#  'evaluation': 403,
#  'median': 404,
#  'arterial': 405,
#  'longus': 406,
#  'basal': 407,
#  'facial': 408,
#  'without': 409,
#  'effusion': 410,
#  'velocity': 411,
#  'dissection': 412,
#  'hydrocephalus': 413,
#  'skin': 414,
#  'aspiration': 415,
#  'descending': 416,
#  'radial': 417,
#  'position': 418,
#  'protrusion': 419,
#  'suture': 420,
#  'headache': 421,
#  'open': 422,
#  'foramina': 423,
#  'kidney': 424,
#  'lesions': 425,
#  'laminectomy': 426,
#  'forearm': 427,
#  'globus': 428,
#  'screws': 429,
#  'extensor': 430,
#  'injury': 431,
#  'patellar': 432,
#  'vasectomy': 433,
#  'vision': 434,
#  'tricuspid': 435,
#  'septum': 436,
#  'glenoid': 437,
#  'cerebellar': 438,
#  'laparoscopy': 439,
#  'cholelithiasis': 440,
#  'endoscope': 441,
#  'status': 442,
#  'wrist': 443,
#  'interphalangeal': 444,
#  'hematuria': 445,
#  'malformation': 446,
#  'ica': 447,
#  'atherosclerotic': 448,
#  'ekg': 449,
#  'gi': 450,
#  'esophagitis': 451,
#  'ileocecal': 452,
#  'osteophyte': 453,
#  'superior': 454,
#  'swallow': 455,
#  'orif': 456,
#  'amplitude': 457,
#  'plateau': 458,
#  'incontinence': 459,
#  'chordee': 460,
#  'vas': 461,
#  'acuity': 462,
#  'regurgitation': 463,
#  'thrombus': 464,
#  'transesophageal': 465,
#  'low': 466,
#  'vascular': 467,
#  'botulinum': 468,
#  'palsy': 469,
#  'infarction': 470,
#  'austin': 471,
#  'vehicle': 472,
#  'femur': 473,
#  'mental': 474,
#  'activity': 475,
#  'feeding': 476,
#  'pronator': 477,
#  'duplex': 478,
#  'maxillary': 479,
#  'seizures': 480,
#  'diarrhea': 481,
#  'radiation': 482,
#  'field': 483,
#  'structures': 484,
#  'stimulation': 485,
#  'surgery': 486,
#  'fluoroscopic': 487,
#  'thickening': 488,
#  'sheath': 489,
#  'ganglion': 490,
#  'anemia': 491,
#  'level': 492,
#  'testicle': 493,
#  'retention': 494,
#  'foreskin': 495,
#  'scope': 496,
#  'elbow': 497,
#  'rectus': 498,
#  'cavernous': 499,
#  'rupture': 500,
#  'cavity': 501,
#  'constipation': 502,
#  'flap': 503,
#  'accident': 504,
#  'consciousness': 505,
#  'toe': 506,
#  'nerves': 507,
#  'studies': 508,
#  'extremities': 509,
#  'extension': 510,
#  'retropubic': 511,
#  'labrum': 512,
#  'sigmoidoscopy': 513,
#  'anastomosis': 514,
#  'mesh': 515,
#  'diverticulosis': 516,
#  'laparotomy': 517,
#  'stent': 518,
#  'colonic': 519,
#  'screening': 520,
#  'fractures': 521,
#  'brachial': 522,
#  'ureteropelvic': 523,
#  'dobutamine': 524,
#  'soft': 525,
#  'swelling': 526,
#  'bones': 527,
#  'epilepsy': 528,
#  'system': 529,
#  'protocol': 530,
#  'monitoring': 531,
#  'glans': 532,
#  'scrotum': 533,
#  'gated': 534,
#  'catgut': 535,
#  'spermatic': 536,
#  'ilioinguinal': 537,
#  'obturator': 538,
#  'ascending': 539,
#  'arthrodesis': 540,
#  'antrum': 541,
#  'thecal': 542,
#  'kidneys': 543,
#  'hemiarthroplasty': 544,
#  'intubation': 545,
#  'tubercle': 546,
#  'herniorrhaphy': 547,
#  'sequential': 548,
#  'radical': 549,
#  'intrauterine': 550,
#  'vomiting': 551,
#  'arthritis': 552,
#  'tract': 553,
#  'pituitary': 554,
#  'spleen': 555,
#  'olecranon': 556,
#  'laceration': 557,
#  'biliary': 558,
#  'gastrointestinal': 559,
#  'neurolysis': 560,
#  'amputation': 561,
#  'snare': 562,
#  'lacunar': 563,
#  'abscess': 564,
#  'subarachnoid': 565,
#  'hemostasis': 566,
#  'hypospadias': 567,
#  'pulley': 568,
#  'index': 569,
#  'calcification': 570,
#  'tibialis': 571,
#  'testicular': 572,
#  'tingling': 573,
#  'neurological': 574,
#  'urethra': 575,
#  'pressure': 576,
#  'medicine': 577,
#  'speech': 578,
#  'blood': 579,
#  'iv': 580,
#  'gyriform': 581,
#  'enhancing': 582,
#  'epicondyle': 583,
#  'vaginal': 584,
#  'antebrachial': 585,
#  'malleolus': 586,
#  'pallidi': 587,
#  'intravenous': 588,
#  'base': 589,
#  'duodenal': 590,
#  'l': 591,
#  'cortisone': 592,
#  'view': 593,
#  'radiofrequency': 594,
#  'injections': 595,
#  'dilatation': 596,
#  'reconstruction': 597,
#  'projections': 598,
#  'clamp': 599,
#  'tibia': 600,
#  'flow': 601,
#  'peak': 602,
#  'bulb': 603,
#  'plaque': 604,
#  'irrigation': 605,
#  'rhythm': 606,
#  'hydronephrosis': 607,
#  'multiple': 608,
#  'migraine': 609,
#  'waveform': 610,
#  'was': 611,
#  'cautery': 612,
#  'pleural': 613,
#  'effusions': 614,
#  'peritoneal': 615,
#  'site': 616,
#  'arm': 617,
#  'metastatic': 618,
#  'parotid': 619,
#  'seminal': 620,
#  'nexgen': 621,
#  'humerus': 622,
#  'pancreas': 623,
#  'flexible': 624,
#  'retinaculum': 625,
#  'deferens': 626,
#  'sprain': 627,
#  'frontotemporal': 628,
#  'gastritis': 629,
#  'fossa': 630,
#  'phenol': 631,
#  'vertigo': 632,
#  'hallux': 633,
#  'placement': 634,
#  'bunion': 635,
#  'glioblastoma': 636,
#  'gland': 637,
#  'electrodes': 638,
#  'branch': 639,
#  'cholangiogram': 640,
#  'abnormal': 641,
#  'hammertoe': 642,
#  'gross': 643,
#  'uterine': 644,
#  'pectoralis': 645,
#  'malnutrition': 646,
#  'thalamic': 647,
#  'sedation': 648,
#  'lightheadedness': 649,
#  'attenuation': 650,
#  'epigastric': 651,
#  'condyle': 652,
#  'sleep': 653,
#  'cartilage': 654,
#  'sterile': 655,
#  'dressing': 656,
#  'interbody': 657,
#  'urogram': 658,
#  'cauda': 659,
#  'equina': 660,
#  'extensors': 661,
#  'ap': 662,
#  'thermocoagulation': 663,
#  'infusion': 664,
#  'papaverine': 665,
#  'bifurcation': 666,
#  'adenopathy': 667,
#  'subluxation': 668,
#  'interstitial': 669,
#  'intramedullary': 670,
#  'shaft': 671,
#  'epididymis': 672,
#  'lexiscan': 673,
#  'obstructive': 674,
#  'contour': 675,
#  'narrowing': 676,
#  'retrograde': 677,
#  'bypass': 678,
#  'orchiopexy': 679,
#  'ring': 680,
#  'crease': 681,
#  'chromic': 682,
#  'tremor': 683,
#  'hyperplasia': 684,
#  'hepatic': 685,
#  'decubitus': 686,
#  'height': 687,
#  'spinenote': 688,
#  'microscopic': 689,
#  'stricture': 690,
#  'uncovertebral': 691,
#  'apophyseal': 692,
#  'fasciotomy': 693,
#  'closed': 694,
#  'cast': 695,
#  'closure': 696,
#  'occipital': 697,
#  'port': 698,
#  'infarct': 699,
#  'drain': 700,
#  'intraoperative': 701,
#  'symptoms': 702,
#  'component': 703,
#  'frequency': 704,
#  'pneumonia': 705,
#  'flexion': 706,
#  'meningioma': 707,
#  'suprasellar': 708,
#  'adenoma': 709,
#  'hemiparesis': 710,
#  'astrocytoma': 711,
#  'shunt': 712,
#  'saphenous': 713,
#  'chondromalacia': 714,
#  'bundle': 715,
#  'osteoarthritis': 716,
#  'painful': 717,
#  'pes': 718,
#  'gastroscope': 719,
#  'colic': 720,
#  'extraaxial': 721,
#  'electrical': 722,
#  'epiphysis': 723,
#  'ge': 724,
#  'torn': 725,
#  'exploratory': 726,
#  'hemiplegia': 727,
#  'discharge': 728,
#  'nodes': 729,
#  'lhermittes': 730,
#  'myelitis': 731,
#  'hemibody': 732,
#  'mci': 733,
#  'guided': 734,
#  'ileum': 735,
#  'bile': 736,
#  'ischemia': 737,
#  'mucosal': 738,
#  'pet': 739,
#  'vesicles': 740,
#  'isovue': 741,
#  'musculature': 742,
#  'brachytherapy': 743,
#  'alzheimers': 744,
#  'neuropsychological': 745,
#  'technetium': 746,
#  'attenuated': 747,
#  'pollicis': 748,
#  'transposition': 749,
#  'foraminotomy': 750,
#  'end': 751,
#  'compressive': 752,
#  'amniotic': 753,
#  'hepatobiliary': 754,
#  'wernickes': 755,
#  'paranasal': 756,
#  'flexors': 757,
#  'reflexes': 758,
#  'saline': 759,
#  'physical': 760,
#  'carm': 761,
#  'spondylolysis': 762,
#  'roots': 763,
#  'graft': 764,
#  'segmental': 765,
#  'processes': 766,
#  'spondylolisthesis': 767,
#  'dementia': 768,
#  'radiograph': 769,
#  'torsion': 770,
#  'resting': 771,
#  'insertion': 772,
#  'ao': 773,
#  'irregular': 774,
#  'mediastinum': 775,
#  'person': 776,
#  't': 777,
#  'cytology': 778,
#  'pouch': 779,
#  'vessels': 780,
#  'loose': 781,
#  'rue': 782,
#  'peripheral': 783,
#  'spacer': 784,
#  'sphenoid': 785,
#  'radicular': 786,
#  'compartment': 787,
#  'retroperitoneal': 788,
#  'progressive': 789,
#  'kerrison': 790,
#  'stereotactic': 791,
#  'stapler': 792,
#  'hyperventilation': 793,
#  'short': 794,
#  'post': 795,
#  'evacuation': 796,
#  'enema': 797,
#  'glands': 798,
#  'epiglottic': 799,
#  'phimosis': 800,
#  'pregnancy': 801,
#  'delivery': 802,
#  'lidocaine': 803,
#  'pericardial': 804,
#  'alignment': 805,
#  'cutaneous': 806,
#  'undescended': 807,
#  'dislocation': 808,
#  'interval': 809,
#  'lv': 810,
#  'adrenal': 811,
#  'growth': 812,
#  'arthrotomy': 813,
#  'capsular': 814,
#  'lymphadenopathy': 815,
#  'fibrillation': 816,
#  'de': 817,
#  'volar': 818,
#  'calcified': 819,
#  'exploration': 820,
#  'bursa': 821,
#  'dyspepsia': 822,
#  'antibiotic': 823,
#  'biceps': 824,
#  'capital': 825,
#  'fiberglass': 826,
#  'femoris': 827,
#  'ataxia': 828,
#  'patellofemoral': 829,
#  'hemisphere': 830,
#  'calvarium': 831,
#  'colostomy': 832,
#  'tissues': 833,
#  'metatarsophalangeal': 834,
#  'hallucis': 835,
#  'airway': 836,
#  'breathing': 837,
#  'marcaine': 838,
#  'fluoroscopy': 839,
#  'mammography': 840,
#  'atrium': 841,
#  'quadrant': 842,
#  'balloon': 843,
#  'epinephrine': 844,
#  'foramen': 845,
#  'modified': 846,
#  'collection': 847,
#  'sphincter': 848,
#  'ventricle': 849,
#  'subscapularis': 850,
#  'paracentesis': 851,
#  'blade': 852,
#  'direct': 853,
#  'mesoappendix': 854,
#  'tunica': 855,
#  'vaginalis': 856,
#  'meniscal': 857,
#  'defect': 858,
#  'vastus': 859,
#  'major': 860,
#  'antral': 861,
#  'differentiated': 862,
#  'cell': 863,
#  'percutaneous': 864,
#  'radionuclide': 865,
#  'a1': 866,
#  'thumb': 867,
#  'planovalgus': 868,
#  'peroneus': 869,
#  'hydroceles': 870,
#  'complete': 871,
#  'impairment': 872,
#  'ruptured': 873,
#  'skull': 874,
#  'arteriovenous': 875,
#  'fcr': 876,
#  'ectopic': 877,
#  'chondroplasty': 878,
#  'gestation': 879,
#  'signal': 880,
#  'laser': 881,
#  'calcaneal': 882,
#  'meniscoplasty': 883,
#  'stage': 884,
#  'gastrojejunal': 885,
#  'triphasic': 886,
#  'air': 887,
#  'desiccation': 888,
#  'flush': 889,
#  'titanium': 890,
#  'foraminotomies': 891,
#  'consultation': 892,
#  'masses': 893,
#  'angina': 894,
#  'kyphoplasty': 895,
#  'paraplegia': 896,
#  'time': 897,
#  'flank': 898,
#  'urine': 899,
#  'abnormalities': 900,
#  'medullary': 901,
#  'aponeurosis': 902,
#  'dartos': 903,
#  'turp': 904,
#  'emergency': 905,
#  'department': 906,
#  'splenic': 907,
#  'colonoscopynote': 908,
#  'inflammation': 909,
#  'dizziness': 910,
#  'acalculous': 911,
#  'cortical': 912,
#  'pole': 913,
#  'perforation': 914,
#  'fistula': 915,
#  'pinning': 916,
#  'swallowing': 917,
#  'vacuum': 918,
#  'subacute': 919,
#  'cardiovascular': 920,
#  'cerebrovascular': 921,
#  'capsule': 922,
#  'moderate': 923,
#  'walker': 924,
#  'lengthening': 925,
#  'fat': 926,
#  'spinous': 927,
#  'encopresis': 928,
#  'cranial': 929,
#  'erectile': 930,
#  'anatomical': 931,
#  'hole': 932,
#  'microdiskectomy': 933,
#  'radius': 934,
#  'ovary': 935,
#  'meatus': 936,
#  'calcium': 937,
#  'scoring': 938,
#  'lad': 939,
#  'rmca': 940,
#  'failure': 941,
#  'gia': 942,
#  'coli': 943,
#  'cemented': 944,
#  'pylorus': 945,
#  'corporal': 946,
#  'refractory': 947,
#  'aspect': 948,
#  'instability': 949,
#  'quervain': 950,
#  'intractable': 951,
#  'biomet': 952,
#  'vessel': 953,
#  'transient': 954,
#  'ophthalmic': 955,
#  'paraclinoid': 956,
#  'aneurysms': 957,
#  'neurologic': 958,
#  'bursitis': 959,
#  'trauma': 960,
#  'morphology': 961,
#  'beads': 962,
#  'slipped': 963,
#  'irritable': 964,
#  'casts': 965,
#  'active': 966,
#  'remote': 967,
#  'brachium': 968,
#  'basilar': 969,
#  'bodies': 970,
#  'formation': 971,
#  'tailor': 972,
#  'abductor': 973,
#  'steroid': 974,
#  'liquid': 975,
#  'electrodiagnostic': 976,
#  'orchiectomy': 977,
#  'ablation': 978,
#  'horizontal': 979,
#  'torcula': 980,
#  'decorticate': 981,
#  'family': 982,
#  'history': 983,
#  'lung': 984,
#  'echogenicity': 985,
#  'aryepiglottic': 986,
#  'jugulodigastric': 987,
#  'pump': 988,
#  'stenosing': 989,
#  'middle': 990,
#  'suprapubic': 991,
#  'deglutition': 992,
#  'severe': 993,
#  'transthoracic': 994,
#  'diabetes': 995,
#  'segment': 996,
#  'rest': 997,
#  'bandage': 998,
#  'photic': 999,
#  'ascites': 1000,
#  ...}

# %%
len(word_index)
# Out:
# 3137

# %%
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_train_padded = pad_sequences(X_train_seq, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
X_test_seq = tokenizer.texts_to_sequences(X_test)
X_test_padded = pad_sequences(X_test_seq, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
max_features = 5000
maxlen = 150
batch_size = 32
embedding_dims = 128
filters = 250
kernel_size = 3
hidden_dims = 500
epochs = 10

# %%
model = Sequential()

# we start off with an efficient embedding layer which maps
# our vocab indices into embedding_dims dimensions
model.add(Embedding(max_features,
                    embedding_dims,
                    input_length=150))
#model.add(Dropout(0.2))

# we add a Convolution1D, which will learn filters
# word group filters of size filter_length:
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))

# we use max pooling:
model.add(GlobalMaxPooling1D())

# We add a vanilla hidden layer:
model.add(Dense(hidden_dims))
model.add(Dropout(0.5))
model.add(Activation('relu'))

# We project onto a single unit output layer, and squash it with a sigmoid:
model.add(Dense(5))
model.add(Activation('softmax'))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\shibly\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 150, 128)          640000
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 148, 250)          96250
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 250)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               125500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# activation_1 (Activation)    (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 2505
# _________________________________________________________________
# activation_2 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 864,255
# Trainable params: 864,255
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X_train_padded, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_split=0.1)
# Out:
# WARNING:tensorflow:From C:\Users\shibly\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\shibly\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 735 samples, validate on 82 samples
# Epoch 1/10
# 735/735 [==============================] - 2s 3ms/step - loss: 1.5704 - accuracy: 0.2748 - val_loss: 1.5319 - val_accuracy: 0.4390
# Epoch 2/10
# 735/735 [==============================] - 2s 2ms/step - loss: 1.4251 - accuracy: 0.3633 - val_loss: 1.3160 - val_accuracy: 0.4512
# Epoch 3/10
# 735/735 [==============================] - 2s 2ms/step - loss: 0.9140 - accuracy: 0.7633 - val_loss: 0.6343 - val_accuracy: 0.7927
# Epoch 4/10
# 735/735 [==============================] - 2s 2ms/step - loss: 0.3343 - accuracy: 0.9116 - val_loss: 0.3911 - val_accuracy: 0.8659
# Epoch 5/10
# 735/735 [==============================] - 2s 2ms/step - loss: 0.1761 - accuracy: 0.9306 - val_loss: 0.4158 - val_accuracy: 0.8659
# Epoch 6/10
# 735/735 [==============================] - 2s 2ms/step - loss: 0.1583 - accuracy: 0.9347 - val_loss: 0.4403 - val_accuracy: 0.8659
# Epoch 7/10
# 735/735 [==============================] - 2s 2ms/step - loss: 0.1661 - accuracy: 0.9293 - val_loss: 0.5094 - val_accuracy: 0.8780
# Epoch 8/10
# 735/735 [==============================] - 2s 2ms/step - loss: 0.1132 - accuracy: 0.9388 - val_loss: 0.4724 - val_accuracy: 0.8780
# Epoch 9/10
# 735/735 [==============================] - 2s 2ms/step - loss: 0.1209 - accuracy: 0.9333 - val_loss: 0.5061 - val_accuracy: 0.8659
# Epoch 10/10
# 735/735 [==============================] - 2s 2ms/step - loss: 0.1233 - accuracy: 0.9347 - val_loss: 0.5226 - val_accuracy: 0.8659

# %%
model.evaluate(X_test_padded, y_test)
# Out:
# 205/205 [==============================] - 0s 647us/step
# [0.7631252809268673, 0.790243923664093]

# %%
y_pred = model.predict_classes(X_test_padded)

# %%
from sklearn import metrics
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, confusion_matrix
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7902439024390244

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.80        43
#            1       1.00      1.00      1.00        29
#            2       0.72      0.83      0.78        60
#            3       0.57      0.51      0.54        45
#            4       0.96      0.96      0.96        28
#
#     accuracy                           0.79       205
#    macro avg       0.82      0.82      0.82       205
# weighted avg       0.79      0.79      0.79       205

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[33,  0,  2,  8,  0],
#        [ 0, 29,  0,  0,  0],
#        [ 0,  0, 50,  9,  1],
#        [ 6,  0, 16, 23,  0],
#        [ 0,  0,  1,  0, 27]], dtype=int64)

# %%
model.save('CNNNotes.h5')

# %%
from keras.models import load_model

# %%
predictor = load_model('CNNNotes.h5')

# %%
y_predict1 = predictor.predict_classes(X_test_padded)

# %%
print(classification_report(y_test, y_predict1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.80        43
#            1       1.00      1.00      1.00        29
#            2       0.72      0.83      0.78        60
#            3       0.57      0.51      0.54        45
#            4       0.96      0.96      0.96        28
#
#     accuracy                           0.79       205
#    macro avg       0.82      0.82      0.82       205
# weighted avg       0.79      0.79      0.79       205

# %%
from io import StringIO 
sample1 = StringIO("""keywords;
                    pyeloplasty, ureteral stent placement, nephrolithotomy, ureteropelvic junction obstruction, jackson-pratt drain, foley catheter, renal pelvis, kidney stones, monocryl sutures, pelvis, renal, ureteropelvic, sutures;
                    sebaceous cyst, prolene suture, incisional hernia, incisional, abscess, hernia, abdomen, omentum, excision, cyst;
                    origin of stalk, extensor retinaculum, wrist ganglion, incision, excision, dorsal, tourniquet, wrist, ganglion;
                    arteriovenous malformation, avm, brain ct, cerebral angiogram, headache, audiogram, carotid bruits, difficulty ambulating, hemorrhage, interventricular hemorrhage, migraine, tinnitus, vertigo, visual change, weakness, episode of vertigo, evaluation
                    """)

    #keywords labeled as 
    #1. urology(labeled as 4) 
    #2. gasternology(labeled as 0) 
    #3. orthopedic(labeled as 2)
    #4. neurology (labeled as 1)
    #first we need to preprocess the example. Store the input texts to a dataframe and preprocess

predictDF = pd.read_csv(sample1, sep =";")
predictDF
# Out:
#                                             keywords  Unnamed: 1
# 0                      pyeloplasty, ureteral sten...         NaN
# 1                      sebaceous cyst, prolene su...         NaN
# 2                      origin of stalk, extensor ...         NaN
# 3                      arteriovenous malformation...         NaN

# %%
import re
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
SPACE_RE = re.compile(' ')
def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    #text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = SPACE_RE.sub(' ', text)
    #text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
    return text

predictDF['keywords'] = predictDF['keywords'].apply(clean_text)
predictDF
# Out:
#                                             keywords  Unnamed: 1
# 0                      pyeloplasty  ureteral sten...         NaN
# 1                      sebaceous cyst  prolene su...         NaN
# 2                      origin of stalk  extensor ...         NaN
# 3                      arteriovenous malformation...         NaN

# %%
X_sample_seq = tokenizer.texts_to_sequences(predictDF.keywords.values)
X_sample_padded = pad_sequences(X_sample_seq, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
y_predict = predictor.predict_classes(X_sample_padded)

# %%
y_predict
# Out:
# array([4, 0, 2, 3], dtype=int64)

# %%
#3 right 1 wrong(neurology)
