# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import csv
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D

# %%
vocab_size = 1000
embedding_dim = 32
max_length = 200
trunc_type = 'post'
padding_type = 'post'
oov_tok = '<OOV>'
training_portion = .8

# %%
df = pd.read_csv('EP1.csv')

# %%
df = df.sample(frac=1)
X = df.prescription.values
y = df.specialty.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 50)

# %%
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
encoder = LabelEncoder()
encoder.fit(y)
y_train = encoder.transform(y_train)
y_test = encoder.transform(y_test)

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(X_train) #only train
word_index = tokenizer.word_index
dict(list(word_index.items()))
# Out:
# {'<OOV>': 1,
#  'hcl': 2,
#  'sodium': 3,
#  'er': 4,
#  'tartrate': 5,
#  'metoprolol': 6,
#  'potassium': 7,
#  'omeprazole': 8,
#  'amlodipine': 9,
#  'calcium': 10,
#  'furosemide': 11,
#  'gabapentin': 12,
#  'besylate': 13,
#  'lisinopril': 14,
#  'succinate': 15,
#  'zolpidem': 16,
#  'pantoprazole': 17,
#  'diltiazem': 18,
#  'prednisone': 19,
#  'chloride': 20,
#  'clopidogrel': 21,
#  'hydrocodoneacetaminophen': 22,
#  'simvastatin': 23,
#  'warfarin': 24,
#  'atorvastatin': 25,
#  'carvedilol': 26,
#  'lorazepam': 27,
#  'losartan': 28,
#  'maleate': 29,
#  'acetate': 30,
#  'divalproex': 31,
#  'hbr': 32,
#  'alprazolam': 33,
#  'hydrochlorothiazide': 34,
#  'clonazepam': 35,
#  'xl': 36,
#  'sertraline': 37,
#  'nexium': 38,
#  'clonidine': 39,
#  'fumarate': 40,
#  'isosorbide': 41,
#  'klorcon': 42,
#  'atenolol': 43,
#  'spironolactone': 44,
#  'bupropion': 45,
#  'levothyroxine': 46,
#  'citalopram': 47,
#  'hr': 48,
#  'pravastatin': 49,
#  'diovan': 50,
#  'allopurinol': 51,
#  'quetiapine': 52,
#  'venlafaxine': 53,
#  'escitalopram': 54,
#  'oxalate': 55,
#  'mesylate': 56,
#  'trazodone': 57,
#  'lamotrigine': 58,
#  'hydralazine': 59,
#  'amoxicillin': 60,
#  'mononitrate': 61,
#  'cymbalta': 62,
#  'carbidopalevodopa': 63,
#  'crestor': 64,
#  'namenda': 65,
#  'donepezil': 66,
#  'xr': 67,
#  'topiramate': 68,
#  'amitriptyline': 69,
#  'ondansetron': 70,
#  'carbamazepine': 71,
#  'tramadol': 72,
#  'fluoxetine': 73,
#  'propranolol': 74,
#  'mirtazapine': 75,
#  'm': 76,
#  'levetiracetam': 77,
#  'digox': 78,
#  'ranitidine': 79,
#  'nifedipine': 80,
#  'paroxetine': 81,
#  'risperidone': 82,
#  'anastrozole': 83,
#  'ramipril': 84,
#  'oxycodone': 85,
#  'renvela': 86,
#  'olanzapine': 87,
#  'lyrica': 88,
#  'enalapril': 89,
#  'sensipar': 90,
#  'citrate': 91,
#  'amiodarone': 92,
#  'xarelto': 93,
#  'sulfate': 94,
#  'tamsulosin': 95,
#  'diazepam': 96,
#  'ropinirole': 97,
#  'famotidine': 98,
#  'verapamil': 99,
#  'pradaxa': 100,
#  'zetia': 101,
#  'nitrostat': 102,
#  'metformin': 103,
#  'dexamethasone': 104,
#  'prochlorperazine': 105,
#  'abilify': 106,
#  'calcitriol': 107,
#  'hydroxyurea': 108,
#  'temazepam': 109,
#  'benicar': 110,
#  'oxcarbazepine': 111,
#  'peg': 112,
#  'dexilant': 113,
#  'ciprofloxacin': 114,
#  'cd': 115,
#  'tamoxifen': 116,
#  'losartanhydrochlorothiazide': 117,
#  'digoxin': 118,
#  'haloperidol': 119,
#  'doxazosin': 120,
#  'phenytoin': 121,
#  'letrozole': 122,
#  'labetalol': 123,
#  'sr': 124,
#  'lisinoprilhydrochlorothiazide': 125,
#  'lansoprazole': 126,
#  'buspirone': 127,
#  'baclofen': 128,
#  'benztropine': 129,
#  'bystolic': 130,
#  'nortriptyline': 131,
#  'alendronate': 132,
#  'primidone': 133,
#  'polyethylene': 134,
#  'glycol': 135,
#  'glipizide': 136,
#  'benazepril': 137,
#  'oxycodoneacetaminophen': 138,
#  'levofloxacin': 139,
#  'fenofibrate': 140,
#  'lovastatin': 141,
#  'lithium': 142,
#  'dihydrochloride': 143,
#  'carbonate': 144,
#  'sotalol': 145,
#  'metoclopramide': 146,
#  'extended': 147,
#  'hydroxyzine': 148,
#  'metolazone': 149,
#  'pramipexole': 150,
#  'azithromycin': 151,
#  'revlimid': 152,
#  'ranexa': 153,
#  'morphine': 154,
#  'valsartanhydrochlorothiazide': 155,
#  'fentanyl': 156,
#  'promethazine': 157,
#  'dicyclomine': 158,
#  'methylphenidate': 159,
#  'bumetanide': 160,
#  'exelon': 161,
#  'azathioprine': 162,
#  'with': 163,
#  'minoxidil': 164,
#  'megestrol': 165,
#  'flavor': 166,
#  'toprol': 167,
#  'sulfamethoxazoletrimethoprim': 168,
#  'triamterenehctz': 169,
#  'diphenoxylateatropine': 170,
#  'exemestane': 171,
#  'xt': 172,
#  'sumatriptan': 173,
#  'ziprasidone': 174,
#  'lidocaineprilocaine': 175,
#  'sucralfate': 176,
#  'lactulose': 177,
#  'hfa': 178,
#  'clozapine': 179,
#  'acyclovir': 180,
#  'hct': 181,
#  'torsemide': 182,
#  'odt': 183,
#  'cyclobenzaprine': 184,
#  'gleevec': 185,
#  'amantadine': 186,
#  'avonex': 187,
#  'seroquel': 188,
#  'zonisamide': 189,
#  'acid': 190,
#  'multaq': 191,
#  'tizanidine': 192,
#  'vytorin': 193,
#  'lantus': 194,
#  'copaxone': 195,
#  'lovaza': 196,
#  'azilect': 197,
#  'amphetamine': 198,
#  'salt': 199,
#  'combo': 200,
#  'niaspan': 201,
#  'bromide': 202,
#  'besylatebenazepril': 203,
#  'cephalexin': 204,
#  'suprep': 205,
#  'nifedical': 206,
#  'terazosin': 207,
#  'trihexyphenidyl': 208,
#  'chlorthalidone': 209,
#  'vimpat': 210,
#  'metronidazole': 211,
#  'oxycontin': 212,
#  'phenobarbital': 213,
#  'cartia': 214,
#  'aggrenox': 215,
#  'effient': 216,
#  'irbesartan': 217,
#  'quinapril': 218,
#  'midodrine': 219,
#  'pyridostigmine': 220,
#  'ibuprofen': 221,
#  'keppra': 222,
#  'januvia': 223,
#  'dilantin': 224,
#  'asacol': 225,
#  'invega': 226,
#  'lamictal': 227,
#  'packs': 228,
#  'flecainide': 229,
#  'amitiza': 230,
#  'mycophenolate': 231,
#  'mofetil': 232,
#  'micardis': 233,
#  'fluphenazine': 234,
#  'moviprep': 235,
#  'ursodiol': 236,
#  'propionate': 237,
#  'acetaminophencodeine': 238,
#  'tegretol': 239,
#  'zemplar': 240,
#  'meloxicam': 241,
#  'tarceva': 242,
#  'colcrys': 243,
#  'coumadin': 244,
#  'galantamine': 245,
#  'pamoate': 246,
#  'fluconazole': 247,
#  'cilostazol': 248,
#  'propafenone': 249,
#  'enoxaparin': 250,
#  'gavilyten': 251,
#  'clindamycin': 252,
#  'lialda': 253,
#  'nitroglycerin': 254,
#  'gemfibrozil': 255,
#  'pen': 256,
#  'hclacetaminophen': 257,
#  'decanoate': 258,
#  'apriso': 259,
#  'fluticasone': 260,
#  'proair': 261,
#  'lunesta': 262,
#  'patch': 263,
#  'advair': 264,
#  'dinitrate': 265,
#  'welchol': 266,
#  'synthroid': 267,
#  'diskus': 268,
#  'oxybutynin': 269,
#  'cr': 270,
#  'risperdal': 271,
#  'doxepin': 272,
#  'fosrenol': 273,
#  'pristiq': 274,
#  'celebrex': 275,
#  'meclizine': 276,
#  'mercaptopurine': 277,
#  'glimepiride': 278,
#  'jantoven': 279,
#  'hydromorphone': 280,
#  'budesonide': 281,
#  'ec': 282,
#  'consta': 283,
#  'fludrocortisone': 284,
#  'zytiga': 285,
#  'carbidopalevodopaentacapone': 286,
#  'xifaxan': 287,
#  'gluconate': 288,
#  'fluvoxamine': 289,
#  'bicalutamide': 290,
#  'depakote': 291,
#  'chlorhexidine': 292,
#  'hd': 293,
#  'exforge': 294,
#  'amox': 295,
#  'trpotassium': 296,
#  'clavulanate': 297,
#  'bisoprolol': 298,
#  'methylprednisolone': 299,
#  'procrit': 300,
#  'balsalazide': 301,
#  'disodium': 302,
#  'modafinil': 303,
#  'montelukast': 304,
#  'pacerone': 305,
#  'and': 306,
#  'electrolytes': 307,
#  'nadolol': 308,
#  'penicillin': 309,
#  'v': 310,
#  'carafate': 311,
#  'rebif': 312,
#  'chlorpromazine': 313,
#  'coreg': 314,
#  'perphenazine': 315,
#  'rivastigmine': 316,
#  'entacapone': 317,
#  'creon': 318,
#  'electrolyte': 319,
#  'spiriva': 320,
#  'finasteride': 321,
#  'evista': 322,
#  'uloric': 323,
#  'cholestyramine': 324,
#  'folic': 325,
#  'valproic': 326,
#  'pentasa': 327,
#  'pioglitazone': 328,
#  'insulin': 329,
#  'syringe': 330,
#  'trilyte': 331,
#  'packets': 332,
#  'naproxen': 333,
#  'dextroamphetamineamphetamine': 334,
#  'novolog': 335,
#  'nystatin': 336,
#  'latuda': 337,
#  'felodipine': 338,
#  'aciphex': 339,
#  'flexpen': 340,
#  'ampyra': 341,
#  'glyburide': 342,
#  'solostar': 343,
#  'tasigna': 344,
#  'prosol': 345,
#  'sustenna': 346,
#  'tekturna': 347,
#  'valacyclovir': 348,
#  'prazosin': 349,
#  'lidoderm': 350,
#  'neupro': 351,
#  'carisoprodol': 352,
#  'thiothixene': 353,
#  'lipitor': 354,
#  'humalog': 355,
#  'eliquis': 356,
#  'aricept': 357,
#  'topamax': 358,
#  'humira': 359,
#  'humulin': 360,
#  'gilenya': 361,
#  'stalevo': 362,
#  'lidocaine': 363,
#  'clomipramine': 364,
#  'bd': 365,
#  'ultrafine': 366,
#  'needle': 367,
#  'colestipol': 368,
#  'eplerenone': 369,
#  'methocarbamol': 370,
#  'anagrelide': 371,
#  'renagel': 372,
#  'sulfasalazine': 373,
#  'doxycycline': 374,
#  'hyclate': 375,
#  'selegiline': 376,
#  'imipramine': 377,
#  'saphris': 378,
#  'methadone': 379,
#  'vitamin': 380,
#  'd': 381,
#  'clarithromycin': 382,
#  'novolin': 383,
#  'tacrolimus': 384,
#  'plavix': 385,
#  'levemir': 386,
#  'rizatriptan': 387,
#  'viibryd': 388,
#  'linzess': 389,
#  'betaseron': 390,
#  'trilipix': 391,
#  'taztia': 392,
#  'sps': 393,
#  'trifluoperazine': 394,
#  'brilinta': 395,
#  'gavilyteg': 396,
#  'la': 397,
#  'gentamicin': 398,
#  'mestinon': 399,
#  'methotrexate': 400,
#  'guanfacine': 401,
#  'vesicare': 402,
#  'loperamide': 403,
#  'acetonide': 404,
#  'epitol': 405,
#  'nuvigil': 406,
#  'azor': 407,
#  'triamcinolone': 408,
#  'bisoprololhydrochlorothiazide': 409,
#  'captopril': 410,
#  'afinitor': 411,
#  'clorazepate': 412,
#  'dipotassium': 413,
#  'thioridazine': 414,
#  'xtandi': 415,
#  'generlac': 416,
#  'gavilytec': 417,
#  'vyvanse': 418,
#  'tecfidera': 419,
#  'ventolin': 420,
#  'delzicol': 421,
#  'lanoxin': 422,
#  'triamterenehydrochlorothiazid': 423,
#  'diclofenac': 424,
#  'carbatrol': 425,
#  'voltaren': 426,
#  'hydrocortisone': 427,
#  'strattera': 428,
#  'hectorol': 429,
#  'r': 430,
#  'acetazolamide': 431,
#  'loxapine': 432,
#  'livalo': 433,
#  'canasa': 434,
#  'kionex': 435,
#  'polystyrene': 436,
#  'sulfonate': 437,
#  'savella': 438,
#  'glycopyrrolate': 439,
#  'pentoxifylline': 440,
#  'jakafi': 441,
#  'tikosyn': 442,
#  'gammagard': 443,
#  'liquid': 444,
#  'ibandronate': 445,
#  'glyburidemetformin': 446,
#  'janumet': 447,
#  'desipramine': 448,
#  'symbicort': 449,
#  'cyclosporine': 450,
#  'ketoconazole': 451,
#  'phosphate': 452,
#  'avodart': 453,
#  'dextroamphetamine': 454,
#  'clotrimazolebetamethasone': 455,
#  'mirapex': 456,
#  'trileptal': 457,
#  'nasonex': 458,
#  'onglyza': 459,
#  'spironolactonehctz': 460,
#  'indomethacin': 461,
#  'lodosyn': 462,
#  'comtan': 463,
#  'lexapro': 464,
#  'fosinopril': 465,
#  'xenazine': 466,
#  'detrol': 467,
#  'baraclude': 468,
#  'sprycel': 469,
#  'fondaparinux': 470,
#  'hydroxychloroquine': 471,
#  'modified': 472,
#  'paricalcitol': 473,
#  'diltxr': 474,
#  'nisoldipine': 475,
#  'amiloride': 476,
#  'viread': 477,
#  'fanapt': 478,
#  'n': 479,
#  'combivent': 480,
#  'nefazodone': 481,
#  'atenololchlorthalidone': 482,
#  'aranesp': 483,
#  'indapamide': 484,
#  'wellbutrin': 485,
#  'niacin': 486,
#  'exjade': 487,
#  'zyprexa': 488,
#  'suboxone': 489,
#  'amlodipineatorvastatin': 490,
#  'triazolam': 491,
#  'gamunexc': 492,
#  'myfortic': 493,
#  'prograf': 494,
#  'bidil': 495,
#  'zaleplon': 496,
#  'halflytelybisacodyl': 497,
#  'etodolac': 498,
#  'leukeran': 499,
#  'rapamune': 500,
#  'aubagio': 501,
#  'viscous': 502,
#  'effexor': 503,
#  'clotrimazole': 504,
#  'liothyronine': 505,
#  'prandin': 506,
#  'nuedexta': 507,
#  'lactate': 508,
#  'pm': 509,
#  'valcyte': 510,
#  'zenpep': 511,
#  'administration': 512,
#  'pack': 513,
#  'onfi': 514,
#  'benazeprilhydrochlorothiazide': 515,
#  'thalomid': 516,
#  'respimat': 517,
#  'requip': 518,
#  'misoprostol': 519,
#  'premarin': 520,
#  'naltrexone': 521,
#  'fenofibric': 522,
#  'actonel': 523,
#  'mupirocin': 524,
#  'sildenafil': 525,
#  'sutent': 526,
#  'sandostatin': 527,
#  'lar': 528,
#  'naratriptan': 529,
#  'neurontin': 530,
#  'chlordiazepoxide': 531,
#  'nitrofurantoin': 532,
#  'mexiletine': 533,
#  'pegasys': 534,
#  'acebutolol': 535,
#  'felbatol': 536,
#  'banzel': 537,
#  'tricor': 538,
#  'neupogen': 539,
#  'proctozonehc': 540,
#  'ktab': 541,
#  'irbesartanhydrochlorothiazide': 542,
#  'oxazepam': 543,
#  'victoza': 544,
#  'pak': 545,
#  'endocet': 546,
#  'cimzia': 547,
#  'trandolapril': 548,
#  'felbamate': 549,
#  'dronabinol': 550,
#  'plus': 551,
#  'emend': 552,
#  'dipyridamole': 553,
#  'amiloridehydrochlorothiazide': 554,
#  'tradjenta': 555,
#  'flovent': 556,
#  'leflunomide': 557,
#  'sinemet': 558,
#  'diphenhydramine': 559,
#  'prepopik': 560,
#  'nexavar': 561,
#  'mix': 562,
#  'estradiol': 563,
#  'omeprazolesodium': 564,
#  'bicarbonate': 565,
#  'dapsone': 566,
#  'theophylline': 567,
#  'tribenzor': 568,
#  'nateglinide': 569,
#  'clinisol': 570,
#  'dextrose': 571,
#  'votrient': 572,
#  'fazaclo': 573,
#  'enulose': 574,
#  'mesalamine': 575,
#  'clobetasol': 576,
#  'rozerem': 577,
#  'timolol': 578,
#  'hydrocodone': 579,
#  'bitibuprofen': 580,
#  'protonix': 581,
#  'atacand': 582,
#  'minocycline': 583,
#  'flurazepam': 584,
#  'af': 585,
#  'nabumetone': 586,
#  'atrovent': 587,
#  'albuterol': 588,
#  'ambien': 589,
#  'cefuroxime': 590,
#  'treximet': 591,
#  'inlyta': 592,
#  'swab': 593,
#  'levocetirizine': 594,
#  'lasix': 595,
#  'tracleer': 596,
#  'chantix': 597,
#  'androgel': 598,
#  'neulasta': 599,
#  'in': 600,
#  'water': 601,
#  'gabitril': 602,
#  'disopyramide': 603,
#  'sure': 604,
#  'comfort': 605,
#  'lotronex': 606,
#  'afeditab': 607,
#  'norvasc': 608,
#  'pomalyst': 609,
#  'relpax': 610,
#  'rocaltrol': 611,
#  'enalaprilhydrochlorothiazide': 612,
#  'zonegran': 613,
#  'cellcept': 614,
#  'methscopolamine': 615,
#  'levocarnitine': 616,
#  'single': 617,
#  'use': 618,
#  'clozaril': 619,
#  'fluocinonide': 620,
#  'proctosolhc': 621,
#  'bethanechol': 622,
#  'butorphanol': 623,
#  'avapro': 624,
#  'quinaprilhydrochlorothiazide': 625,
#  'ethosuximide': 626,
#  'anhydrous': 627,
#  'zostavax': 628,
#  'adcirca': 629,
#  'prozac': 630,
#  'cardizem': 631,
#  'azelastine': 632,
#  'zomig': 633,
#  'olanzapinefluoxetine': 634,
#  'betamethasone': 635,
#  'stivarga': 636,
#  'simcor': 637,
#  'transdermscop': 638,
#  'folbic': 639,
#  'avastin': 640,
#  'sf': 641,
#  'butalbital': 642,
#  'compoundcodeine': 643,
#  'codeine': 644,
#  'cyclophosphamide': 645,
#  'epivir': 646,
#  'osmoprep': 647,
#  'potiga': 648,
#  'ammonium': 649,
#  'caps': 650,
#  'mometasone': 651,
#  'furoate': 652,
#  'light': 653,
#  'neoral': 654,
#  'remeron': 655,
#  'cyproheptadine': 656,
#  'calcitoninsalmon': 657,
#  'acarbose': 658,
#  'proclick': 659,
#  'promacta': 660,
#  'monomacro': 661,
#  'unifine': 662,
#  'pentips': 663,
#  'alfuzosin': 664,
#  'travatan': 665,
#  'z': 666,
#  'rapaflo': 667,
#  'promethegan': 668,
#  'alcohol': 669,
#  'rilutek': 670,
#  'buprenorphinenaloxone': 671,
#  'extavia': 672,
#  'prevacid': 673,
#  'intralipid': 674,
#  'buprenorphine': 675,
#  'matzim': 676,
#  'atelvia': 677,
#  'cozaar': 678,
#  'rituxan': 679,
#  'phoslyra': 680,
#  'prevident': 681,
#  'niacor': 682,
#  'femara': 683,
#  'perphenazineamitriptyline': 684,
#  'dipropionate': 685,
#  'octreotide': 686,
#  'sod': 687,
#  'succ': 688,
#  'pataday': 689,
#  'herceptin': 690,
#  'moexipril': 691,
#  'nitrolingual': 692,
#  'hbv': 693,
#  'bromocriptine': 694,
#  'depakene': 695,
#  'cefadroxil': 696,
#  'prevalite': 697,
#  'chlordiazepoxideamitriptyline': 698,
#  'orap': 699,
#  'zelapar': 700,
#  'gengraf': 701,
#  'folbee': 702,
#  'faslodex': 703,
#  'opana': 704,
#  'nucynta': 705,
#  'novofine': 706,
#  'tasmar': 707,
#  'desmopressin': 708,
#  'ribapak': 709,
#  'dulera': 710,
#  'pylera': 711,
#  'fluorouracil': 712,
#  'avelox': 713,
#  'demeclocycline': 714,
#  'botox': 715,
#  'metaxalone': 716,
#  'phenelzine': 717,
#  'geodon': 718,
#  'actos': 719,
#  'tykerb': 720,
#  'nystatintriamcinolone': 721,
#  'qvar': 722,
#  'butalbcaffacetaminophcodein': 723,
#  'candesartan': 724,
#  'cilexetil': 725,
#  'pilocarpine': 726,
#  'butalbitalacetaminophencaffe': 727,
#  'edarbi': 728,
#  'proventil': 729,
#  'riluzole': 730,
#  'solumedrol': 731,
#  'nitrodur': 732,
#  'rythmol': 733,
#  'latanoprost': 734,
#  'ipratropium': 735,
#  'gralise': 736,
#  'budeprion': 737,
#  'estazolam': 738,
#  'phenytek': 739,
#  'mepron': 740,
#  'pioglitazonemetformin': 741,
#  'needles': 742,
#  'flector': 743,
#  'letairis': 744,
#  'kombiglyze': 745,
#  'betaxolol': 746,
#  'danazol': 747,
#  'pindolol': 748,
#  'voriconazole': 749,
#  'imitrex': 750,
#  'dihydroergotamine': 751,
#  'focalin': 752,
#  'zelboraf': 753,
#  'ribavirin': 754,
#  'hp': 755,
#  'acthar': 756,
#  'ketorolac': 757,
#  'tromethamine': 758,
#  'migranal': 759,
#  'ascomp': 760,
#  'enbrel': 761,
#  'zometa': 762,
#  'alimta': 763,
#  'methyldopa': 764,
#  'candesartanhydrochlorothiazid': 765,
#  'methamphetamine': 766,
#  'renal': 767,
#  'tenormin': 768,
#  'milrinone': 769,
#  'sabril': 770,
#  'atripla': 771,
#  'famciclovir': 772,
#  'tarka': 773,
#  'tiagabine': 774,
#  'flurbiprofen': 775,
#  'mysoline': 776,
#  'relistor': 777,
#  'trimethobenzamide': 778,
#  'iv': 779,
#  'aq': 780,
#  'ativan': 781,
#  'erythromycin': 782,
#  'erytab': 783,
#  'discmelt': 784,
#  'targretin': 785,
#  'velcade': 786,
#  'celontin': 787,
#  'phospha': 788,
#  'neutral': 789,
#  'lamivudine': 790,
#  'methenamine': 791,
#  'hippurate': 792,
#  'sulfazine': 793,
#  'piroxicam': 794,
#  'cytra': 795,
#  'tranylcypromine': 796,
#  'brimonidine': 797,
#  'vascepa': 798,
#  'enablex': 799,
#  'arimidex': 800,
#  'ribasphere': 801,
#  'prevpac': 802,
#  'heparin': 803,
#  'ticlopidine': 804,
#  'valerate': 805,
#  'ritalin': 806,
#  'rifampin': 807,
#  'testosterone': 808,
#  'cypionate': 809,
#  'xyrem': 810,
#  'probenecid': 811,
#  'neomycinpolymyxinhc': 812,
#  'neomycinpolymyxinhydrocort': 813,
#  'fortical': 814,
#  'sodiummisoprostol': 815,
#  'xgeva': 816,
#  'prednisolone': 817,
#  'xopenex': 818,
#  'viagra': 819,
#  'reno': 820,
#  'chlorzoxazone': 821,
#  'rx': 822,
#  'adderall': 823,
#  'nifediac': 824,
#  'cc': 825,
#  'cimetidine': 826,
#  'restasis': 827,
#  'glucagon': 828,
#  'emergency': 829,
#  'kit': 830,
#  'tysabri': 831,
#  'isradipine': 832,
#  'methimazole': 833,
#  'ees': 834,
#  'eryped': 835,
#  'pancreaze': 836,
#  'solaraze': 837,
#  'desloratadine': 838,
#  'tyvaso': 839,
#  'revatio': 840,
#  'toviaz': 841,
#  'liptruzet': 842,
#  'aromasin': 843,
#  'nitrobid': 844,
#  'sectral': 845,
#  'imdur': 846,
#  'byetta': 847,
#  'sensitive': 848,
#  'ketoprofen': 849,
#  'xalkori': 850,
#  'trueplus': 851,
#  'pancrelipase': 852,
#  'denta': 853,
#  'nalbuphine': 854,
#  'pexeva': 855,
#  'epogen': 856,
#  'quinidine': 857,
#  'perindopril': 858,
#  'erbumine': 859,
#  'hydrocodonehomatropine': 860,
#  'mbr': 861,
#  'lescol': 862,
#  'ultram': 863,
#  'nephrocaps': 864,
#  'triphrocaps': 865,
#  'protriptyline': 866,
#  'colocort': 867,
#  'inspra': 868,
#  'cialis': 869,
#  'hyoscyamine': 870,
#  'actigall': 871,
#  'tofranilpm': 872,
#  'lipofen': 873,
#  'estropipate': 874,
#  'oxaliplatin': 875,
#  'paclitaxel': 876,
#  'carboplatin': 877,
#  'zoledronic': 878,
#  'isentress': 879,
#  'crixivan': 880,
#  'propylthiouracil': 881,
#  'zidovudine': 882,
#  'butrans': 883,
#  'repaglinide': 884,
#  'xanax': 885,
#  'armour': 886,
#  'thyroid': 887,
#  'golytely': 888,
#  'relprevv': 889,
#  'maintena': 890,
#  'travasol': 891,
#  'methazolamide': 892,
#  'nutropin': 893,
#  'amoxapine': 894,
#  'benzonatate': 895,
#  'aloxi': 896,
#  'syprine': 897,
#  'ulticare': 898,
#  'androderm': 899,
#  'zoloft': 900,
#  'aplenzin': 901,
#  'orphenadrine': 902,
#  'methylergonovine': 903,
#  'nplate': 904,
#  'flunisolide': 905,
#  'thiola': 906,
#  'sulindac': 907,
#  'strovite': 908,
#  'one': 909,
#  'proscar': 910,
#  'provigil': 911,
#  'monoject': 912,
#  'edarbyclor': 913,
#  'zydis': 914,
#  'arixtra': 915,
#  'levoxyl': 916,
#  'kristalose': 917,
#  'prenatal': 918,
#  'ipratropiumalbuterol': 919,
#  'permethrin': 920,
#  'norpace': 921,
#  'tamiflu': 922,
#  'vancomycin': 923,
#  'singulair': 924,
#  'monurol': 925,
#  'cubicin': 926,
#  'doribax': 927,
#  'lamivudinezidovudine': 928,
#  'aldactone': 929,
#  'nicotrol': 930,
#  'ciprodex': 931,
#  'bydureon': 932,
#  'pennsaid': 933,
#  'reyataz': 934,
#  'micronized': 935,
#  'norvir': 936,
#  'paxil': 937,
#  'fragmin': 938,
#  'daytrana': 939,
#  'valtrex': 940,
#  'intuniv': 941,
#  'trospium': 942,
#  'remicade': 943,
#  'silenor': 944,
#  'cardura': 945,
#  'samsca': 946,
#  'durezol': 947,
#  'dorzolamide': 948,
#  'ofloxacin': 949,
#  'nevirapine': 950,
#  'vicodin': 951,
#  'tobramycindexamethasone': 952,
#  'apokyn': 953,
#  'octagam': 954,
#  'zafirlukast': 955,
#  'beconase': 956,
#  'vitald': 957,
#  'qualaquin': 958,
#  'tekamlo': 959,
#  'sprinkle': 960,
#  'fluoride': 961,
#  'inderal': 962,
#  'frova': 963,
#  'stavudine': 964,
#  'dantrolene': 965,
#  'peganone': 966,
#  'ciclopirox': 967,
#  'daliresp': 968,
#  'theo': 969,
#  'lumigan': 970,
#  'azopt': 971,
#  'bepreve': 972,
#  'combigan': 973,
#  'patanol': 974,
#  'dicloxacillin': 975,
#  'cromolyn': 976,
#  'ampicillin': 977,
#  'trihydrate': 978,
#  'prep': 979,
#  'pads': 980,
#  'alphagan': 981,
#  'p': 982,
#  'betapace': 983,
#  'lupron': 984,
#  'depot': 985,
#  'zmt': 986,
#  'forteo': 987,
#  'percocet': 988,
#  'prolia': 989,
#  'erbitux': 990,
#  'granisetron': 991,
#  'colyte': 992,
#  'antara': 993,
#  'chlorothiazide': 994,
#  'promethazinecodeine': 995,
#  'anafranil': 996,
#  'duloxetine': 997,
#  'roxicet': 998,
#  'cortifoam': 999,
#  'salsalate': 1000,
#  ...}

# %%
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_train_padded = pad_sequences(X_train_seq, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
X_train_seq[500]
# Out:
# [173,
#  15,
#  379,
#  2,
#  35,
#  161,
#  65,
#  187,
#  256,
#  63,
#  197,
#  317,
#  22,
#  187,
#  210,
#  97,
#  2,
#  419,
#  195,
#  63,
#  4,
#  77,
#  71,
#  12,
#  150,
#  143,
#  227,
#  133,
#  69,
#  2,
#  52,
#  40,
#  21,
#  316,
#  66,
#  2,
#  31,
#  3,
#  4,
#  37,
#  2,
#  99,
#  4,
#  186,
#  85,
#  257,
#  131,
#  2,
#  58,
#  213,
#  74,
#  2,
#  68]

# %%
X_test_seq = tokenizer.texts_to_sequences(X_test)
X_test_padded = pad_sequences(X_test_seq, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
encoder.inverse_transform([0,1,2,3,4,5,6])
# Out:
# array(['cardiovasculardisease', 'gastroenterology', 'generalpractice',
#        'hematologyoncology', 'nephrology', 'neurology', 'psychiatry'],
#       dtype=object)

# %%
max_features = 5000
maxlen = 80
batch_size = 32
embedding_dims = 128
filters = 250
kernel_size = 3
hidden_dims = 250
epochs = 10

# %%
model = Sequential()

# we start off with an efficient embedding layer which maps
# our vocab indices into embedding_dims dimensions
model.add(Embedding(max_features,
                    embedding_dims,
                    input_length=200))
#model.add(Dropout(0.2))

# we add a Convolution1D, which will learn filters
# word group filters of size filter_length:
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
# we use max pooling:
model.add(GlobalMaxPooling1D())

# We add a vanilla hidden layer:
model.add(Dense(hidden_dims))
model.add(Dropout(0.2))
model.add(Activation('relu'))

# We project onto a single unit output layer, and squash it with a sigmoid:
model.add(Dense(7))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 200, 128)          640000
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 198, 250)          96250
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 250)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 250)               62750
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 250)               0
# _________________________________________________________________
# activation_5 (Activation)    (None, 250)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 1757
# _________________________________________________________________
# activation_6 (Activation)    (None, 7)                 0
# =================================================================
# Total params: 800,757
# Trainable params: 800,757
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X_train_padded, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_split=0.1)
# Out:
# Train on 1516 samples, validate on 169 samples
# Epoch 1/10
# 1516/1516 [==============================] - 4s 3ms/step - loss: 1.3760 - accuracy: 0.6550 - val_loss: 0.4666 - val_accuracy: 0.8876
# Epoch 2/10
# 1516/1516 [==============================] - 4s 3ms/step - loss: 0.2818 - accuracy: 0.9354 - val_loss: 0.1970 - val_accuracy: 0.9527
# Epoch 3/10
# 1516/1516 [==============================] - 4s 3ms/step - loss: 0.1226 - accuracy: 0.9690 - val_loss: 0.2113 - val_accuracy: 0.9586
# Epoch 4/10
# 1516/1516 [==============================] - 4s 3ms/step - loss: 0.0713 - accuracy: 0.9815 - val_loss: 0.2169 - val_accuracy: 0.9527
# Epoch 5/10
# 1516/1516 [==============================] - 4s 3ms/step - loss: 0.0452 - accuracy: 0.9894 - val_loss: 0.2269 - val_accuracy: 0.9586
# Epoch 6/10
# 1516/1516 [==============================] - 4s 3ms/step - loss: 0.0257 - accuracy: 0.9960 - val_loss: 0.2300 - val_accuracy: 0.9645
# Epoch 7/10
# 1516/1516 [==============================] - 4s 3ms/step - loss: 0.0178 - accuracy: 0.9974 - val_loss: 0.2552 - val_accuracy: 0.9586
# Epoch 8/10
# 1516/1516 [==============================] - 4s 2ms/step - loss: 0.0159 - accuracy: 0.9967 - val_loss: 0.2596 - val_accuracy: 0.9645
# Epoch 9/10
# 1516/1516 [==============================] - 4s 3ms/step - loss: 0.0117 - accuracy: 0.9974 - val_loss: 0.2752 - val_accuracy: 0.9586
# Epoch 10/10
# 1516/1516 [==============================] - 4s 3ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.2668 - val_accuracy: 0.9645

# %%
model.evaluate(X_test_padded, y_test)
# Out:
# 422/422 [==============================] - 0s 667us/step
# [0.24354841042553038, 0.950236976146698]

# %%
y_pred = model.predict_classes(X_test_padded)

# %%
from sklearn import metrics
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, confusion_matrix
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9502369668246445

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94        63
#            1       0.98      0.91      0.94        56
#            2       0.96      1.00      0.98        50
#            3       1.00      0.97      0.98        60
#            4       0.90      0.97      0.93        66
#            5       0.97      0.90      0.93        69
#            6       0.90      0.98      0.94        58
#
#     accuracy                           0.95       422
#    macro avg       0.95      0.95      0.95       422
# weighted avg       0.95      0.95      0.95       422

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[59,  0,  0,  0,  3,  0,  1],
#        [ 1, 51,  1,  0,  2,  0,  1],
#        [ 0,  0, 50,  0,  0,  0,  0],
#        [ 0,  1,  0, 58,  0,  1,  0],
#        [ 1,  0,  0,  0, 64,  1,  0],
#        [ 1,  0,  0,  0,  2, 62,  4],
#        [ 0,  0,  1,  0,  0,  0, 57]], dtype=int64)

# %%
model.save('CNNPrescription.h5')

# %%
from keras.models import load_model
predictor = load_model('CNNPrescription.h5')

# %%
y_predict1 = predictor.predict_classes(X_test_padded)

# %%
print(classification_report(y_test, y_predict1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94        63
#            1       0.98      0.91      0.94        56
#            2       0.96      1.00      0.98        50
#            3       1.00      0.97      0.98        60
#            4       0.90      0.97      0.93        66
#            5       0.97      0.90      0.93        69
#            6       0.90      0.98      0.94        58
#
#     accuracy                           0.95       422
#    macro avg       0.95      0.95      0.95       422
# weighted avg       0.95      0.95      0.95       422

# %%
from io import StringIO 
sample1 = StringIO("""prescription;
                    trilyte with flavor packets  gavilyten  lansoprazole  nexium  omeprazole  prevalite  asacol hd  pantoprazole sodium  ursodiol  spironolactone  azathioprine  dicyclomine hcl;
                    levofloxacin  letrozole  tamoxifen citrate  dexamethasone  exemestane  prochlorperazine maleate  warfarin sodium  anastrozole  hydrocodoneacetaminophen  potassium chloride  megestrol acetate  klorcon m  alprazolam  ondansetron hcl;
                    amoxicillin;
                    calcium acetate  bisoprololhydrochlorothiazide  allopurinol  potassium citrate  amlodipine besylate;
    
                    """)

    #keywords labeled as 
    #1. gasternology(labeled as 1) 
    #2. hematologyoncology(labeled as 3) 
    #3. generalpractice(labeled as 2)
    #4. nephrology (labeled as 4)
    #first we need to preprocess the example. Store the input texts to a dataframe and preprocess

predictDF = pd.read_csv(sample1, sep =";")


predictDF
# Out:
#                                         prescription  Unnamed: 1
# 0                      trilyte with flavor packet...         NaN
# 1                      levofloxacin  letrozole  t...         NaN
# 2                                        amoxicillin         NaN
# 3                      calcium acetate  bisoprolo...         NaN

# %%
import re
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
SPACE_RE = re.compile(' ')
def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    #text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = SPACE_RE.sub(' ', text)
    #text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
    return text

predictDF['prescription'] = predictDF['prescription'].apply(clean_text)
predictDF
# Out:
#                                         prescription  Unnamed: 1
# 0                      trilyte with flavor packet...         NaN
# 1                      levofloxacin  letrozole  t...         NaN
# 2                                        amoxicillin         NaN
# 3                      calcium acetate  bisoprolo...         NaN

# %%
X_sample_seq = tokenizer.texts_to_sequences(predictDF.prescription.values)
X_sample_padded = pad_sequences(X_sample_seq, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
y_predict = predictor.predict_classes(X_sample_padded)

# %%
y_predict
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
#4 right 0 wrong
